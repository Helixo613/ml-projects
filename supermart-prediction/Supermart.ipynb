# %% [markdown]
# # Library Imports
# Importing the essential libraries for data handling, visualization, and machine learning.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Loading the Dataset
# Reading the dataset from a CSV file into a DataFrame for further analysis.

# %%
df=pd.read_csv(r'C:\Users\ASUS\Desktop\Arnav\PYTHON\miscellaneous\internship\week1\day2\SampleSuperstore.csv',encoding='latin1')
y = df['Profit']
x = df.drop(['Profit'],axis=1)
y1 = df['Sales']
x2 = df.drop(['Sales'],axis=1)

# %% [markdown]
# # Dataset Preview
# Displaying the first few rows of the dataset to get an initial look at the data.

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # Summary Statistics
# Generating statistical summaries of numeric features.

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# # Dataset Dimensions
# Checking the number of rows and columns in the dataset.

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# # Checking Missing Values
# Counting missing values in each column.

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# # Visualizing Missing Data
# Visualizing the missing values using a heatmap.

# %%
missing_data=df.isnull()
sns.heatmap(missing_data, cbar=False, cmap='inferno')
# Out:
# <Axes: >

# %%
sum_missing = df.isnull().sum()

# %%
percentage = (sum_missing/len(df))*100
print (percentage)
# Out:
# Row ID           0.0
# Order ID         0.0
# Order Date       0.0
# Ship Date        0.0
# Ship Mode        0.0
# Customer ID      0.0
# Customer Name    0.0
# Segment          0.0
# Country          0.0
# City             0.0
# State            0.0
# Postal Code      0.0
# Region           0.0
# Product ID       0.0
# Category         0.0
# Sub-Category     0.0
# Product Name     0.0
# Sales            0.0
# Quantity         0.0
# Discount         0.0
# Profit           0.0
# dtype: float64

# %% [markdown]
# # Histograms of Sales and Profit
# Visualizing distributions of Sales and Profit.

# %%
ax = sns.histplot(data=df, x='Sales')
ax = sns.histplot(data=df, x='Profit')

# %%
plt.figure()
ax1 = sns.boxplot(data=df, x='Sales')
plt.figure()
ax2 = sns.boxplot(data=df, x='Profit')

# %% [markdown]
# # Correlation Heatmap
# Heatmap to visualize correlation between numeric variables.

# %%
plt.figure()
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# %% [markdown]
# # Date Features Extraction
# Extracting additional features from the order and ship dates.

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df['Order Year'] = df['Order Date'].dt.year
df['Order Month'] = df['Order Date'].dt.month
df['Ship Delay'] = (df['Ship Date'] - df['Order Date']).dt.days
df[['Order Date', 'Ship Date', 'Order Year', 'Order Month', 'Ship Delay']].head()
# Out:
#   Order Date  Ship Date  Order Year  Order Month  Ship Delay
# 0 2016-11-08 2016-11-11        2016           11           3
# 1 2016-11-08 2016-11-11        2016           11           3
# 2 2016-06-12 2016-06-16        2016            6           4
# 3 2015-10-11 2015-10-18        2015           10           7
# 4 2015-10-11 2015-10-18        2015           10           7

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# ...

# %% [markdown]
# # Data Encoding and cleaning
# Encoding categorical features into numerical values.

# %%
#Encoding data
df_cleaned = df.drop(['Order ID', 'Customer ID', 'Customer Name', 'Product ID', 'Product Name'], axis=1)
df_encoded = pd.get_dummies(df_cleaned, drop_first=True)
df_encoded.head()
# Out:
#    Row ID Order Date  Ship Date  Postal Code     Sales  Quantity  Discount  \
# 0       1 2016-11-08 2016-11-11        42420  261.9600         2      0.00
# 1       2 2016-11-08 2016-11-11        42420  731.9400         3      0.00
# 2       3 2016-06-12 2016-06-16        90036   14.6200         2      0.00
# 3       4 2015-10-11 2015-10-18        33311  957.5775         5      0.45
# 4       5 2015-10-11 2015-10-18        33311   22.3680         2      0.20
#
#      Profit  Order Year  Order Month  ...  Sub-Category_Envelopes  \
# 0   41.9136        2016           11  ...                   False
# 1  219.5820        2016           11  ...                   False
# 2    6.8714        2016            6  ...                   False
# 3 -383.0310        2015           10  ...                   False
# 4    2.5164        2015           10  ...                   False
#
#    Sub-Category_Fasteners  Sub-Category_Furnishings  Sub-Category_Labels  \
# ...

# %%
df_encoded['Profitable']=df_encoded['Profit'].apply(lambda x: 1 if x > 0 else 0)

# %%
#Removing outliers
from scipy import stats
numeric_data=df_encoded.select_dtypes(include=[np.number])
z_score=np.abs(stats.zscore(numeric_data))
df_no_outliers = df_encoded[(z_score < 3).all(axis=1)]

# %%
df_no_outliers.head()
# Out:
#    Row ID Order Date  Ship Date  Postal Code     Sales  Quantity  Discount  \
# 0       1 2016-11-08 2016-11-11        42420  261.9600         2      0.00
# 1       2 2016-11-08 2016-11-11        42420  731.9400         3      0.00
# 2       3 2016-06-12 2016-06-16        90036   14.6200         2      0.00
# 3       4 2015-10-11 2015-10-18        33311  957.5775         5      0.45
# 4       5 2015-10-11 2015-10-18        33311   22.3680         2      0.20
#
#      Profit  Order Year  Order Month  ...  Sub-Category_Fasteners  \
# 0   41.9136        2016           11  ...                   False
# 1  219.5820        2016           11  ...                   False
# 2    6.8714        2016            6  ...                   False
# 3 -383.0310        2015           10  ...                   False
# 4    2.5164        2015           10  ...                   False
#
#    Sub-Category_Furnishings  Sub-Category_Labels  Sub-Category_Machines  \
# ...

# %%
df_no_outliers.shape
# Out:
# (9436, 616)

# %%
#Applying Scaling
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
df_scaled=df_no_outliers.select_dtypes(include=[np.number])
df_scaled.head()
# Out:
#    Row ID  Postal Code     Sales  Quantity  Discount    Profit  Order Year  \
# 0       1        42420  261.9600         2      0.00   41.9136        2016
# 1       2        42420  731.9400         3      0.00  219.5820        2016
# 2       3        90036   14.6200         2      0.00    6.8714        2016
# 3       4        33311  957.5775         5      0.45 -383.0310        2015
# 4       5        33311   22.3680         2      0.20    2.5164        2015
#
#    Order Month  Ship Delay  Profitable
# 0           11           3           1
# 1           11           3           1
# 2            6           4           1
# 3           10           7           0
# 4           10           7           1

# %% [markdown]
# # Feature and Target Separation
# Separating the target variable from the input features.

# %%
from sklearn.model_selection import train_test_split
X=df_scaled.drop(['Profit'],axis=1)
Y=df_scaled['Profit']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.model_selection import train_test_split
X_class = df_scaled.drop(['Profit'], axis=1)
y_class = df_encoded.loc[X_class.index, 'Profitable']
X_train_clf, X_test_clf, y_train_clf, y_test_clf = train_test_split(X_class, y_class, test_size=0.2, random_state=42)

# %% [markdown]
# # Model Training and Prediction
# Training a regression model and making predictions.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

model=LinearRegression()
model.fit(X_train,Y_train)
Y_pred= model.predict(X_test)
r2 = r2_score(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)
print(f'R² Score: {r2}')
print(f'Mean Squared Error: {mse}')
# Out:
# R² Score: 0.3302394986432544
# Mean Squared Error: 4546.441621955597

# %%
plt.figure(figsize=(8, 6))
plt.scatter(Y_test, Y_pred,alpha=0.5)
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], 'r--')
plt.xlabel('Actual Profit')
plt.ylabel('Predicted Profit')
plt.title('Actual vs Predicted Profit')
plt.grid(True)
plt.show()

# %%
print(df_encoded['Profitable'].value_counts())
# Out:
# Profitable
# 1    8058
# 0    1936
# Name: count, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

log_model = LogisticRegression(class_weight='balanced', max_iter=1000, solver='liblinear')
log_model.fit(X_train_clf, y_train_clf)
y_pred_clf = log_model.predict(X_test_clf)

print("Accuracy:", accuracy_score(y_test_clf, y_pred_clf))
print("Confusion Matrix:\n", confusion_matrix(y_test_clf, y_pred_clf))
print("Classification Report:\n", classification_report(y_test_clf, y_pred_clf))
# Out:
# Accuracy: 1.0
# Confusion Matrix:
#  [[ 352    0]
#  [   0 1536]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       352
#            1       1.00      1.00      1.00      1536
#
#     accuracy                           1.00      1888
#    macro avg       1.00      1.00      1.00      1888
# weighted avg       1.00      1.00      1.00      1888

# %%
cm = confusion_matrix(y_test_clf, y_pred_clf)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Logistic Regression")
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train_clf,y_train_clf)
y_pred_dt = dt_model.predict(X_test_clf)
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

print("Accuracy:", accuracy_score(y_test_clf, y_pred_dt))
print("Classification Report:\n", classification_report(y_test_clf, y_pred_dt))
# Out:
# Accuracy: 1.0
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       352
#            1       1.00      1.00      1.00      1536
#
#     accuracy                           1.00      1888
#    macro avg       1.00      1.00      1.00      1888
# weighted avg       1.00      1.00      1.00      1888
